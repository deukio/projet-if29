# %% [markdown]
# # PROJET IF29

# %% [markdown]
# ## Première étape : preprocessing

# %% [markdown]
# Les importations nécessaire :

# %%
import os
import time
import json
import csv
from datetime import datetime
import cProfile
import pstats
import functools
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib notebook

# %% [markdown]
# **Définition des données**
#
# On utilise une définition des données orienté-objet pour avoir une sélection des caractéristiques modulaire.
# On définit donc ici une classe Account représentant un compte twitter
#
# Il possède les caractéristiques classiques d'un compte :
# - identifiant
# - date de création
# - longueur de la biographie
# - nombre de followers
# - nombre de "friends"
#
# ainsi que des caractéristiques moyennes sur les tweets :
# - nombre de tweet trouvés
# - nombre moyen de #, @ et url
#
# Un Account possède trois méthodes : création à partir d'un tweet (constructeur), mise à jour au vu d'un autre tweet (update) et toCSV qui permet de transmettre les caractéristiques importantes, sous le bon format.

# %%
class Account:
    def __init__(self,tweet):
        self.creation_date = (datetime.now()-datetime.strptime(tweet['user']['created_at'],"%a %b %d %H:%M:%S +0000 %Y")).total_seconds()/(60*60*24)
        self.verified = tweet['user']['verified']
        try:
            self.bio_length = len(tweet['user']['description'])
        except:
            self.bio_length = 0
        self.id = tweet['user']['id']

        self.tweet_count = 1
        self.follow_count = tweet['user']['friends_count']
        self.followers_count = tweet['user']['followers_count']
        self.tweet_length = len(tweet['text'])
        
        self.url_by_tweet = tweet['text'].count("http")
        self.hashtag_by_tweet = tweet['text'].count('#')
        self.reference_by_tweet = tweet['text'].count("@")


    def update(self,tweet):
        self.tweet_count += 1
        self.follow_count += tweet['user']['friends_count']
        self.followers_count += tweet['user']['followers_count']
        self.tweet_length += len(tweet['text'])
        self.url_by_tweet += tweet['text'].count("http")
        self.hashtag_by_tweet += tweet['text'].count('#')
        self.reference_by_tweet = tweet['text'].count("@")


    def toCSV(self):
        self.follow_count /= self.tweet_count
        self.followers_count /= self.tweet_count
        self.tweet_length /= self.tweet_count
        self.url_by_tweet /= self.tweet_count
        self.reference_by_tweet /= self.tweet_count
        self.hashtag_by_tweet /= self.tweet_count
        aggressiveness = (self.tweet_count+self.url_by_tweet)/self.creation_date*self.follow_count
        visibility = (self.hashtag_by_tweet*11.4+self.reference_by_tweet*11.6)/140
        danger = self.url_by_tweet 
        return self.id,aggressiveness,visibility,danger

# %% [markdown]
# **Traitement**
#
# La partie suivante est la partie de traitement des données.
# Chaque tweet est passé en revue et ajouté au compte correspondant.
#
# La sauvegarde puis l'écriture des comptes se fait par paquet (batch) pour ne pas remplir la mémoire.
#
# On utilise un profiler pour observer le temps de chaque étape, dans un soucis d'optimisation.

# %%
def main(size=2285,batch=10):
    start_time = time.time()
    accounts = {}
    tweetcount=0
    for index in tqdm(range(size)):
        with open('données/raw/raw{}.json'.format(str(index)),encoding='UTF-8') as file:
            for tweet in (json.loads(line) for line in file):
                tweetcount+=1
                name = tweet['user']['name']
                if name not in accounts:
                    accounts[name] = Account(tweet)
                else:
                    accounts[name].update(tweet)
        if (index+1)%batch==0:
            with open('données/cleaned/clean{}.csv'.format(str(index//batch)),'w',encoding='UTF-8',newline="") as cleanfile:
                writer = csv.writer(cleanfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL).writerow
                for account in accounts.values():
                        writer(account.toCSV())
                        del account
            accounts = {}
    print("--- %s seconds ---" % (time.time() - start_time))

def profiler(func):
    cProfile.run(func,'{}.profile'.format(func))
    stats = pstats.Stats('{}.profile'.format(func))
    stats.strip_dirs().sort_stats('time').print_stats()
    
profiler('main(size=100,batch=10)')
# Out:
# 100%|██████████| 100/100 [00:36<00:00,  2.31it/s]
# --- 36.40813875198364 seconds ---
# Wed Jun 16 17:09:34 2021    main(size=100,batch=10).profile
#
#          8446188 function calls (8446013 primitive calls) in 36.410 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    199999   13.315    0.000   13.315    0.000 decoder.py:343(raw_decode)
#    200099    7.837    0.000   23.181    0.000 <ipython-input-3-155cc3ab23df>:7(<genexpr>)
#       110    5.327    0.048    5.327    0.048 {built-in method io.open}
#         1    2.387    2.387   36.410   36.410 <ipython-input-3-155cc3ab23df>:1(main)
#    158376    1.612    0.000    3.105    0.000 _strptime.py:318(_strptime)
#    158638    0.840    0.000    0.840    0.000 {built-in method _codecs.utf_8_decode}
#    158376    0.582    0.000    4.537    0.000 <ipython-input-2-fc6dbefccfb4>:2(__init__)
#    558374    0.581    0.000    0.581    0.000 {method 'match' of 're.Pattern' objects}
#    158376    0.564    0.000    0.564    0.000 {method 'writerow' of '_csv.writer' objects}
#    199999    0.325    0.000   13.998    0.000 decoder.py:332(decode)
#    158376    0.295    0.000    0.295    0.000 {built-in method _locale.setlocale}
#    158376    0.258    0.000    3.363    0.000 _strptime.py:574(_strptime_datetime)
#    199999    0.228    0.000   14.310    0.000 __init__.py:299(loads)
#    599997    0.209    0.000    0.209    0.000 {method 'count' of 'str' objects}
#    158638    0.192    0.000    1.033    0.000 codecs.py:319(decode)
#    158376    0.160    0.000    0.160    0.000 <ipython-input-2-fc6dbefccfb4>:31(toCSV)
#    158376    0.159    0.000    0.159    0.000 {method 'groupdict' of 're.Match' objects}
#    158376    0.158    0.000    0.158    0.000 {built-in method now}
#    158376    0.149    0.000    0.205    0.000 locale.py:384(normalize)
#    158376    0.136    0.000    3.499    0.000 {built-in method strptime}
#    316752    0.097    0.000    0.097    0.000 {method 'index' of 'list' objects}
#    158376    0.095    0.000    0.673    0.000 locale.py:571(getlocale)
#    158376    0.093    0.000    0.093    0.000 {method 'total_seconds' of 'datetime.timedelta' objects}
# 875909/875864    0.093    0.000    0.093    0.000 {built-in method builtins.len}
#     41623    0.090    0.000    0.136    0.000 <ipython-input-2-fc6dbefccfb4>:21(update)
#      1649    0.083    0.000    0.083    0.000 {method 'acquire' of '_thread.lock' objects}
#    158376    0.081    0.000    0.755    0.000 _strptime.py:26(_getlang)
#    158376    0.078    0.000    0.283    0.000 locale.py:467(_parse_localename)
#    475153    0.074    0.000    0.074    0.000 {method 'get' of 'dict' objects}
#    200001    0.061    0.000    0.061    0.000 {method 'startswith' of 'str' objects}
#    558374    0.061    0.000    0.061    0.000 {method 'end' of 're.Match' objects}
#    517149    0.050    0.000    0.050    0.000 {built-in method builtins.isinstance}
#    475128    0.047    0.000    0.047    0.000 {method 'lower' of 'str' objects}
#    316752    0.036    0.000    0.036    0.000 {method 'toordinal' of 'datetime.date' objects}
#    158376    0.021    0.000    0.021    0.000 {method 'keys' of 'dict' objects}
#       618    0.012    0.000    0.012    0.000 socket.py:337(send)
#       618    0.002    0.000    0.016    0.000 iostream.py:197(schedule)
#       101    0.001    0.000    0.111    0.001 _tqdm.py:993(__iter__)
#       206    0.001    0.000    0.085    0.000 threading.py:534(wait)
#       205    0.001    0.000    0.095    0.000 iostream.py:337(flush)
#       101    0.001    0.000    0.003    0.000 _tqdm.py:255(format_meter)
#       413    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#       207    0.001    0.000    0.001    0.000 threading.py:216(__init__)
#       713    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#       823    0.001    0.000    0.002    0.000 threading.py:1080(is_alive)
#       206    0.001    0.000    0.084    0.000 threading.py:264(wait)
#       101    0.001    0.000    0.001    0.000 _tqdm.py:968(format_dict)
#       104    0.001    0.000    0.011    0.000 iostream.py:386(write)
#       101    0.001    0.000    0.106    0.001 _tqdm.py:242(fp_write)
#       824    0.001    0.000    0.001    0.000 threading.py:1038(_wait_for_tstate_lock)
#       105    0.001    0.000    0.070    0.001 ansitowin32.py:193(write_plain_text)
#       618    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#       101    0.000    0.000    0.110    0.001 _tqdm.py:1301(display)
#       207    0.000    0.000    0.002    0.000 threading.py:499(__init__)
#       101    0.000    0.000    0.004    0.000 _tqdm.py:983(__repr__)
#       105    0.000    0.000    0.071    0.001 ansitowin32.py:177(write_and_convert)
#       105    0.000    0.000    0.001    0.000 ansitowin32.py:245(convert_osc)
#       100    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#       105    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       105    0.000    0.000    0.001    0.000 _tqdm.py:93(release)
#       105    0.000    0.000    0.001    0.000 _tqdm.py:89(acquire)
#       201    0.000    0.000    0.001    0.000 _tqdm.py:172(format_interval)
#       101    0.000    0.000    0.106    0.001 _tqdm.py:248(print_status)
#       104    0.000    0.000    0.002    0.000 iostream.py:323(_schedule_flush)
#       210    0.000    0.000    0.000    0.000 {method 'finditer' of 're.Pattern' objects}
#      34/1    0.000    0.000    0.001    0.001 sre_parse.py:475(_parse)
#       105    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#      45/1    0.000    0.000    0.000    0.000 sre_compile.py:71(_compile)
#       827    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#       200    0.000    0.000    0.000    0.000 _tqdm.py:213(ema)
#       104    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#       206    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#       105    0.000    0.000    0.071    0.001 ansitowin32.py:160(write)
#       105    0.000    0.000    0.071    0.001 ansitowin32.py:40(write)
#       207    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#       824    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       207    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#       100    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#       105    0.000    0.000    0.001    0.000 _tqdm.py:100(__exit__)
#       206    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#       105    0.000    0.000    0.001    0.000 _tqdm.py:97(__enter__)
#       503    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       207    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#       303    0.000    0.000    0.000    0.000 {built-in method time.time}
#      52/8    0.000    0.000    0.000    0.000 sre_parse.py:174(getwidth)
#       134    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       105    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       106    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#       216    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#       205    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#       278    0.000    0.000    0.000    0.000 sre_parse.py:164(__getitem__)
#        26    0.000    0.000    0.000    0.000 sre_compile.py:276(_optimize_charset)
#       104    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       207    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       207    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       692    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       112    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        10    0.000    0.000    0.000    0.000 {built-in method _csv.writer}
#       8/1    0.000    0.000    0.001    0.001 sre_parse.py:417(_parse_sub)
#         1    0.000    0.000    0.003    0.003 _tqdm.py:708(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#       144    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#       105    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       208    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _utils.py:214(_environ_cols_windows)
#         4    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         1    0.000    0.000   36.410   36.410 <string>:1(<module>)
#         2    0.000    0.000    0.001    0.000 _tqdm.py:1154(close)
#        26    0.000    0.000    0.000    0.000 sre_compile.py:249(_compile_charset)
#       108    0.000    0.000    0.000    0.000 sre_parse.py:172(append)
#         1    0.000    0.000   36.410   36.410 {built-in method builtins.exec}
#       124    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.001    0.001 _tqdm.py:459(__new__)
#        80    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#         2    0.000    0.000    0.000    0.000 __init__.py:373(__getitem__)
#         3    0.000    0.000    0.001    0.000 re.py:271(_compile)
#         1    0.000    0.000    0.000    0.000 _strptime.py:247(pattern)
#         1    0.000    0.000    0.000    0.000 synchronize.py:50(__init__)
#         1    0.000    0.000    0.000    0.000 tempfile.py:142(rng)
#        10    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:488(_decr_instances)
#        45    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#        68    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#         2    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 context.py:69(RLock)
#         7    0.000    0.000    0.000    0.000 sre_parse.py:84(opengroup)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:481(_get_free_pos)
#         1    0.000    0.000    0.000    0.000 threading.py:758(__init__)
#        30    0.000    0.000    0.000    0.000 sre_parse.py:286(tell)
#        46    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         1    0.000    0.000    0.001    0.001 _monitor.py:32(__init__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         8    0.000    0.000    0.000    0.000 random.py:224(_randbelow)
#        70    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#         1    0.000    0.000    0.001    0.001 sre_compile.py:759(compile)
#         1    0.000    0.000    0.000    0.000 threading.py:335(notify)
#        17    0.000    0.000    0.000    0.000 sre_parse.py:343(_escape)
#        10    0.000    0.000    0.000    0.000 sre_parse.py:408(_uniq)
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x00000213FF5B3E18}
#         1    0.000    0.000    0.001    0.001 threading.py:829(start)
#         2    0.000    0.000    0.000    0.000 __init__.py:366(__getattr__)
#         1    0.000    0.000    0.000    0.000 threading.py:1000(join)
#         1    0.000    0.000    0.000    0.000 _monitor.py:50(exit)
#         8    0.000    0.000    0.000    0.000 random.py:256(choice)
#        89    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       2/1    0.000    0.000    0.000    0.000 sre_compile.py:461(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 __init__.py:8(_make_name)
#         1    0.000    0.000    0.000    0.000 random.py:97(seed)
#        57    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         1    0.000    0.000    0.001    0.001 sre_parse.py:919(parse)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:536(_compile_info)
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 sre_parse.py:267(getuntil)
#        10    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 re.py:307(_subx)
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.print}
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:81(__init__)
#         3    0.000    0.000    0.000    0.000 threading.py:1214(current_thread)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:1036(expand_template)
#         1    0.000    0.000    0.000    0.000 tempfile.py:153(__next__)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 _utils.py:183(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:492(_get_charset_prefix)
#        16    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         7    0.000    0.000    0.000    0.000 sre_parse.py:96(closegroup)
#         2    0.000    0.000    0.001    0.000 _tqdm.py:1173(fp_write)
#         1    0.000    0.000    0.000    0.000 threading.py:968(_stop)
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#       6/5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         5    0.000    0.000    0.000    0.000 sre_compile.py:423(_simple)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:103(create_mp_lock)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         9    0.000    0.000    0.000    0.000 sre_compile.py:65(_combine_flags)
#         1    0.000    0.000    0.000    0.000 enum.py:836(__and__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:562(get_lock)
#         1    0.000    0.000    0.000    0.000 synchronize.py:186(__init__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         5    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 sre_parse.py:224(__init__)
#        14    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 _utils.py:169(_is_utf)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         2    0.000    0.000    0.000    0.000 enum.py:284(__call__)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:598(_code)
#         1    0.000    0.000    0.000    0.000 tempfile.py:156(<listcomp>)
#         1    0.000    0.000    0.000    0.000 re.py:313(filter)
#         3    0.000    0.000    0.000    0.000 sre_compile.py:453(_get_iscased)
#         1    0.000    0.000    0.001    0.001 _strptime.py:270(compile)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:990(__hash__)
#         1    0.000    0.000    0.000    0.000 context.py:232(get_context)
#         3    0.000    0.000    0.001    0.000 re.py:232(compile)
#         2    0.000    0.000    0.000    0.000 enum.py:526(__new__)
#         2    0.000    0.000    0.000    0.000 ansitowin32.py:28(__getattr__)
#         1    0.000    0.000    0.000    0.000 threading.py:513(set)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:67(__len__)
#         7    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:232(status_printer)
#         1    0.000    0.000    0.000    0.000 _utils.py:132(__eq__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         5    0.000    0.000    0.000    0.000 sre_parse.py:168(__setitem__)
#         1    0.000    0.000    0.000    0.000 threading.py:728(_newname)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 synchronize.py:90(_make_methods)
#         1    0.000    0.000    0.000    0.000 types.py:164(__get__)
#         1    0.000    0.000    0.000    0.000 random.py:88(__init__)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:986(_comparable)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:903(fix_flags)
#         1    0.000    0.000    0.000    0.000 threading.py:1120(daemon)
#         7    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:965(__del__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:1189(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _monitor.py:98(report)
#         1    0.000    0.000    0.000    0.000 threading.py:358(notify_all)
#         2    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:484(<genexpr>)
#         1    0.000    0.000    0.000    0.000 enum.py:628(value)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:595(isstring)
#         8    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 _utils.py:199(_environ_cols_wrapper)
#         1    0.000    0.000    0.000    0.000 context.py:196(get_start_method)
#         1    0.000    0.000    0.000    0.000 util.py:48(debug)
#         1    0.000    0.000    0.000    0.000 threading.py:1104(daemon)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:113(create_th_lock)
#         1    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:87(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFBA32F6BA0}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}

# %% [markdown]
# **ouverture et standardisation**

# %%
frames = [pd.read_csv("données/cleaned/"+file,sep=',') for file in os.listdir("données/cleaned")]

for frame in frames:
    frame.columns = ["id","aggressivity","visibility","danger"]
    
df = pd.concat(frames)

df_id = df.iloc[:,0]
df = df.drop(df.columns[0],axis=1)

scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)

# %% [markdown]
# Affichage 3d des données

# %%
def plot3d(data,labels,titre,cmap="bwr"):
    fig = plt.figure()
    fig.suptitle(titre)
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(data[:,0],data[:,1],data[:,2],c=labels,alpha=1)
    ax.set_xlabel('aggressiveness')
    ax.set_ylabel('visibility')
    ax.set_zlabel('danger')
    ax.invert_yaxis()
    plt.show()
    
plot3d(scaled_df,np.full((1,scaled_df.shape[1]),0.5),"données")

# %% [markdown]
# ## Deuxième étape : clustering

# %% [markdown]
# ### Kmeans

# %%
km = KMeans(5).fit_predict(scaled_df)

plot3d(scaled_df,km,"KMeans")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### DBSCAN

# %%
dbs = DBSCAN(1.5,30).fit_predict(scaled_df)*-1

plot3d(scaled_df,dbs,"DBSCAN")

# %%
ee = EllipticEnvelope(contamination=0.18,support_fraction=0.6).fit_predict(scaled_df)

plot3d(scaled_df,ee,"eliptic")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
IsF = IsolationForest(contamination=0.01).fit_predict(scaled_df)*-1

plot3d(scaled_df,IsF,"Isolation Forest")
# Out:
# C:\Users\valer\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\valer\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
LoF = LocalOutlierFactor().fit_predict(scaled_df)

plot3d(scaled_df,LoF,"Local outlier factor")
# Out:
# C:\Users\valer\Anaconda3\lib\site-packages\sklearn\neighbors\lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Deuxième étape : SVM

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

print("\nSVM:")

X_train, X_test, y_train, y_test = train_test_split(scaled_df, km, test_size=0.30)

svm = SVC(random_state=42)
svm.fit(X_train[:],y_train[:])

prd = svm.predict(X_test)
prd2 = svm.predict(scaled_df)
plot3d(scaled_df,prd2,"SVM")
# Out:
# SVM:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71269d6d77a1> in <module>
#       5 print("\nSVM:")
#       6
# ----> 7 X_train, X_test, y_train, y_test = train_test_split(scaled_df, km, test_size=0.30)
#       8
#       9 svm = SVC(random_state=42)
#
# NameError: name 'scaled_df' is not defined
